# %%
import pandas as pd

# %%
base_path = "Resources/weather_data/rainfall/data (1).csv" 

header_row = pd.read_csv(base_path, nrows=0).columns[0]
data = pd.read_csv(base_path, skiprows=4)


data
# Out:
#         ID                    Name       State  Value  \
# 0   CA-001          Alameda County  California   3.44
# 1   CA-003           Alpine County  California   9.02
# 2   CA-005           Amador County  California   6.46
# 3   CA-007            Butte County  California   6.45
# 4   CA-009        Calaveras County  California   6.52
# 5   CA-011           Colusa County  California   3.09
# 6   CA-013     Contra Costa County  California   2.68
# 7   CA-015        Del Norte County  California  14.06
# 8   CA-017        El Dorado County  California   9.00
# 9   CA-019           Fresno County  California   2.86
# 10  CA-021            Glenn County  California   3.18
# 11  CA-023         Humboldt County  California  12.15
# 12  CA-025         Imperial County  California   0.32
# 13  CA-027             Inyo County  California   1.00
# 14  CA-029             Kern County  California   2.22
# 15  CA-031            Kings County  California   1.36
# ...
